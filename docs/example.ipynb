# %%
from goa import algorithms, problems

# %% [markdown]
# # Problem examples

# %%
ackley_problem = problems.Ackley(bounds=(-2.5, 2.5))
ackley_problem.plot()
# Out:
# (<Figure size 864x576 with 1 Axes>, <Axes3DSubplot:>)

# %%
quadratic_problem = problems.Quadratic(bounds=(-2.5, 2.5))
quadratic_problem.plot()
# Out:
# (<Figure size 864x576 with 1 Axes>, <Axes3DSubplot:>)

# %% [markdown]
# # Memetic Differential Evolution algorithm
# ### (using Coordinate Method with Simple Descent Direction)

# %%
algorithms.memetic_differential_evolution(
    problem=ackley_problem,
    local_search_algorithm=algorithms.coordinate_method,
    animation_filepath='./media/01-MDE.gif'
)
# Out:
# Terminated at Iteration: 3
# array([[ 8.00178019e-05, -1.19088265e-05],
#        [ 1.08204047e-04, -3.45232652e-05],
#        [ 6.84840536e-05, -9.45822144e-06],
#        [-1.93126931e-05,  4.03870644e-05],
#        [ 2.17583059e-05,  3.00522846e-05],
#        [-1.89509137e-05,  5.05652166e-05],
#        [ 1.16068837e-04, -4.69969899e-05],
#        [ 1.11680610e-05,  3.41367729e-05],
#        [ 5.12390136e-05, -2.89468376e-05],
#        [ 3.59986365e-05, -2.58216919e-05]])

# %%
algorithms.memetic_differential_evolution(
    problem=quadratic_problem,
    local_search_algorithm=algorithms.coordinate_method,
    animation_filepath='./media/02-MDE.gif'
)
# Out:
# Terminated at Iteration: 1
# array([[ 3.37766889e-05, -7.98168709e-06],
#        [ 3.54762506e-05,  7.52493105e-05],
#        [ 3.83504164e-05,  1.00364539e-05],
#        [-2.14920857e-05, -1.85419330e-05],
#        [ 4.52165056e-05,  5.91150395e-05],
#        [-2.95487029e-05,  3.59649504e-05],
#        [ 9.67812098e-07, -1.53859059e-06],
#        [-4.82400051e-05,  3.01774281e-05],
#        [ 3.25716183e-05,  6.13217519e-05],
#        [ 3.99169654e-05, -2.07760586e-05]])

# %% [markdown]
# # Differential Evolution algorithm

# %%
algorithms.differential_evolution(
    ackley_problem,
    animation_filepath='./media/01-DE.gif'
)
# Out:
# Iteration:    5 | RMSE: 1.08811595
# Iteration:   10 | RMSE: 0.46009039
# Iteration:   15 | RMSE: 0.04063142
# Iteration:   20 | RMSE: 0.00936270
# Iteration:   25 | RMSE: 0.00180586
# Iteration:   30 | RMSE: 0.00067661
# Iteration:   35 | RMSE: 0.00036696
# Terminated at Iteration: 38
# array([[ 6.54494520e-05, -7.64307706e-05],
#        [ 1.34315298e-05, -1.16629776e-05],
#        [-2.62047942e-05,  5.66883762e-06],
#        [-4.43955505e-05,  5.96543341e-06],
#        [ 2.50682134e-06,  4.18849450e-06],
#        [ 4.81441934e-06, -2.08929937e-05],
#        [ 4.58562549e-06, -5.61990310e-05],
#        [ 2.00173853e-05,  2.06040751e-05],
#        [-2.95705000e-08, -6.03605460e-06],
#        [ 1.77573366e-05,  8.33507441e-06]])

# %%
algorithms.differential_evolution(
    quadratic_problem,
    animation_filepath='./media/02-DE.gif'
)
# Out:
# Iteration:    5 | RMSE: 0.22396580
# Iteration:   10 | RMSE: 0.01424279
# Iteration:   15 | RMSE: 0.00044331
# Terminated at Iteration: 19
# array([[ 0.0033545 ,  0.00086312],
#        [ 0.01024614, -0.00046486],
#        [-0.00245605, -0.00535413],
#        [ 0.00689089, -0.01008366],
#        [ 0.00367167,  0.01673706],
#        [ 0.00858325, -0.00706966],
#        [ 0.00957509, -0.00238862],
#        [-0.00737504, -0.01268221],
#        [ 0.00099165, -0.01298889],
#        [-0.00540784,  0.00462116]])
